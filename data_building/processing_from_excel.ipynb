# %% [markdown]
# # For asset managers

# %%
import pandas as pd

# %%
df = pd.read_excel('./target_companies_switzerland.xlsx')

# %%
df.iloc[2:]
# Out:
#      List of portfolio managers and trustees licensed by FINMA and monitored by a supervisory organisation  \
# 2                                                  Name
# 3             "Commercial" Treuhand- und Verwaltungs AG
# 4                                      1.618 Capital AG
# 5                                     1788 Capital S.A.
# 6                                         1L Capital AG
# ...                                                 ...
# 1449                     Zürcher Balmelli & Partners SA
# 1450                                     Zuri-Invest AG
# 1451                     Zürisee Investment Partners AG
# 1452                                                NaN
# 1453  Total number of portfolio managers and trustee...
#
#      Unnamed: 1         Unnamed: 2 Unnamed: 3  \
# 2          City  Portfolio Manager    Trustee
# 3        Zürich                  X        NaN
# 4           Zug                  X        NaN
# 5        Genève                  X        NaN
# ...

# %%
df_clean = df.iloc[2:]

df_clean.columns = df.iloc[2].values
df_clean = df_clean.iloc[1:]

df_clean.head()
# Out:
#                                         Name    City Portfolio Manager  \
# 3  "Commercial" Treuhand- und Verwaltungs AG  Zürich                 X
# 4                           1.618 Capital AG     Zug                 X
# 5                          1788 Capital S.A.  Genève                 X
# 6                              1L Capital AG  Zürich                 X
# 7                           2C Advisors Sarl  Genève                 X
#
#   Trustee                           Supervisory organisation
# 3     NaN                               FINcontrol Suisse AG
# 4     NaN      OSFIN Organisation de surveillance financière
# 5     NaN  AOOS - Schweizerische Aktiengesellschaft für A...
# 6     NaN                               FINcontrol Suisse AG
# 7     NaN  SO-FIT Organisme de Surveillance pour Interméd...

# %%
df_clean.to_csv('./target_swiss_clean.csv')

# %%
df_clean[df_clean['City'] == 'Zürich']
# Out:
#                                            Name    City Portfolio Manager  \
# 3     "Commercial" Treuhand- und Verwaltungs AG  Zürich                 X
# 6                                 1L Capital AG  Zürich                 X
# 8                              2trade group ltd  Zürich                 X
# 12                               47 Heritage AG  Zürich                 X
# 17        A.J.K. Wealth Management (Schweiz) AG  Zürich                 X
# ...                                         ...     ...               ...
# 1442                               Zacharias AG  Zürich                 X
# 1443         Zantke Asset Management Schweiz AG  Zürich                 X
# 1444                         Zeltner & Co. GmbH  Zürich                 X
# 1450                             Zuri-Invest AG  Zürich                 X
# 1451             Zürisee Investment Partners AG  Zürich                 X
#
#      Trustee                           Supervisory organisation
# ...

# %%
df_clean[df_clean['City'] == 'Zug']
# Out:
#                                  Name City Portfolio Manager Trustee  \
# 4                    1.618 Capital AG  Zug                 X     NaN
# 10                         3Worlds AG  Zug                 X     NaN
# 13                      4e Capital AG  Zug                 X     NaN
# 24    ABRIAS Investment Management AG  Zug                 X     NaN
# 25         Abts & De Maertelaere GmbH  Zug                 X     NaN
# ...                               ...  ...               ...     ...
# 1342                TRIUS Partners AG  Zug                 X     NaN
# 1350                  Tune Capital AG  Zug                 X     NaN
# 1351                    Turcapital AG  Zug                 X     NaN
# 1389                       VertexA AG  Zug                 X     NaN
# 1407                        Walens AG  Zug                 X     NaN
#
#                                Supervisory organisation
# 4         OSFIN Organisation de surveillance financière
# ...

# %%
df_clean[df_clean['City'] == 'Genève']
# Out:
#                       Name    City Portfolio Manager Trustee  \
# 5        1788 Capital S.A.  Genève                 X     NaN
# 7         2C Advisors Sarl  Genève                 X     NaN
# 9      3T Family Office SA  Genève                 X     NaN
# 16     A&T Alpha Credit SA  Genève                 X     NaN
# 23               Abeloo SA  Genève                 X     NaN
# ...                    ...     ...               ...     ...
# 1429           Wibagest SA  Genève                 X     NaN
# 1433         WM Capital SA  Genève                 X     NaN
# 1434  WOODSTONE CAPITAL SA  Genève                 X     NaN
# 1441  Z Impact Ventures SA  Genève                 X     NaN
# 1446               Zeno SA  Genève                 X     NaN
#
#                                Supervisory organisation
# 5     AOOS - Schweizerische Aktiengesellschaft für A...
# 7     SO-FIT Organisme de Surveillance pour Interméd...
# 9     SO-FIT Organisme de Surveillance pour Interméd...
# ...

# %%
df_clean[df_clean['Name'] == 'Black Oak Family Office SA']
# Out:
#                            Name    City Portfolio Manager Trustee  \
# 239  Black Oak Family Office SA  Genève                 X     NaN
#
#                               Supervisory organisation
# 239  AOOS - Schweizerische Aktiengesellschaft für A...

# %% [markdown]
# # For commodity trading firms

# %%
import pandas as pd

# %%
df = pd.read_excel('./data/public_eye_commodity_trading_firms.xlsx', sheet_name='Database')

# %%
df.head()
# Out:
#                       Swiss commodity trading sector  \
# 0                      Name (Hyperlinked to website)
# 1                                                NaN
# 2                  Active Energy Trading (EMEA) Sàrl
# 3  Addax Petroleum Limited, Douglas, succursale d...
# 4                            AMCI International GmbH
#
#   In orange, trading companies pursuing some extractive activities\n\nIn blue, pure commodity traders  \
# 0                                              Place
# 1                                                NaN
# 2                                             Genève
# 3                                    Chêne-Bougeries
# 4                                                Zug
#
#       Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 0  Capital (CHF)              IDE    Website
# 1            NaN              NaN        NaN
# 2          20000  CHE-415.776.732          X
# 3     USD 10 000  CHE-101.159.589          X
# ...

# %%
df_test = df

df_test.columns = df_test.iloc[0].values

df_test.iloc[1:].head()
# Out:
#                        Name (Hyperlinked to website)            Place  \
# 1                                                NaN              NaN
# 2                  Active Energy Trading (EMEA) Sàrl           Genève
# 3  Addax Petroleum Limited, Douglas, succursale d...  Chêne-Bougeries
# 4                            AMCI International GmbH              Zug
# 5                       Areti International Group SA           Genève
#
#   Capital (CHF)              IDE Website Area of activities (Group level)  \
# 1           NaN              NaN     NaN            Upstream (extractive)
# 2         20000  CHE-415.776.732       X                                X
# 3    USD 10 000  CHE-101.159.589       X                                X
# 4        100000  CHE-101.957.504       X                                X
# 5        100000  CHE-243.057.179       X                                X
#
#        NaN        NaN         NaN Commodity family (Group level)  \
# ...

# %%
df_test['Name (Hyperlinked to website)'].iloc[2]
# Out:
# 'Active Energy Trading (EMEA) Sàrl'
