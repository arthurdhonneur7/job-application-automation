# %% [markdown]
# # Let's fetch the emails given our built csv files

# %%
import pandas as pd
import requests
import json

# %%
df = pd.read_csv('../data_building/final_data/geneva.csv')

# %%
df.head()
# Out:
#                             name  \
# 0              1788 Capital S.A.
# 1            3T Family Office SA
# 2            A&T Alpha Credit SA
# 3                      Abeloo SA
# 4  ACCURATE WEALTH MANAGEMENT SA
#
#                                             linkedin                  domain  \
# 0      https://www.linkedin.com/company/1788-capital     www.1788capital.com
# 1                                              False  www.3tfamilyoffice.com
# 2  https://ch.linkedin.com/company/a-t-alpha-cred...         alpha-credit.ch
# 3                                              False            abeloo.swiss
# 4  https://www.linkedin.com/company/accuratewealt...   www.accuratewealth.ch
#
#                           website total_emails generic_emails personal_emails  \
# 0    https://www.1788capital.com/            1              0               1
# 1  http://www.3tfamilyoffice.com/            1              0               1
# ...
